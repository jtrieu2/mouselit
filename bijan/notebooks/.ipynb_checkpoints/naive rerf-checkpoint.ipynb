# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load results from running Dockerized "deep-conv-rf"

# %%
acc_v_n = np.load("naive_rf_pyrerf_acc_vs_n.npy")
acc_v_n.shape
# Out:
# (20, 10, 3)

# %%
plt.plot(np.linspace(10,100,20),[1-i['train'] for i in acc_v_n[:,0,2]], label='train')
plt.plot(np.linspace(10,100,20),[1-i['test'] for i in acc_v_n[:,0,2]], label='test')
plt.legend(loc=0)
plt.title('naive rerf on fashion mnist')
plt.ylabel('acc')
plt.xlabel('n')
plt.show()
